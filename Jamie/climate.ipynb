# %%
# Dependancies
import pandas as pd
import numpy as np
from pprint import pprint

# %%
# read census csv into df
census_df = pd.read_csv('census.csv')
census_df
# Out:
#     Unnamed: 0  Median Age  Population  Poverty Count  Household Income  \
# 0            0        40.1   3468963.0      1543220.0           19775.0
# 1            1        38.7   4850771.0       849699.0           46472.0
# 2            2        33.9    738565.0        73380.0           76114.0
# 3            3        37.2   6809946.0      1128046.0           53510.0
# 4            4        37.9   2977944.0       524211.0           43813.0
# 5            5        36.1  38982847.0      5773408.0           67169.0
# 6            6        36.5   5436519.0       612143.0           65458.0
# 7            7        40.8   3594478.0       350783.0           73781.0
# 8            8        33.9    672391.0       111025.0           77649.0
# 9            9        39.8    943732.0       111304.0           63036.0
# 10          10        41.8  20278447.0      3070972.0           50883.0
# 11          11        36.4  10201635.0      1679030.0           52977.0
# ...

# %%
# read average annual temperature by state csv into df
avg_temp_df = pd.read_csv('avg_temp.csv')
avg_temp_df
# Out:
#              State  avg_F  Avg_C  Rank
# 0          Alabama   62.8   17.1     7
# 1           Alaska   26.6   -3.0    50
# 2          Arizona   60.3   15.7    10
# 3         Arkansas   60.4   15.8     9
# 4       California   59.4   15.2    12
# 5         Colorado   45.1    7.3    39
# 6      Connecticut   49.0    9.4    29
# 7         Delaware   55.3   12.9    16
# 8          Florida   70.7   21.5     1
# 9          Georgia   63.5   17.5     5
# 10          Hawaii   70.0   21.1     2
# 11           Idaho   44.4    6.9    40
# 12        Illinois   51.8   11.0    23
# 13         Indiana   51.7   10.9    25
# 14            Iowa   47.8    8.8    36
# 15          Kansas   54.3   12.4    19
# 16        Kentucky   55.6   13.1    15
# 17       Louisiana   66.4   19.1     3
# 18           Maine   41.0    5.0    48
# 19        Maryland   54.2   12.3    20
# 20   Massachusetts   47.9    8.8    35
# 21        Michigan   44.4    6.9    40
# 22       Minnesota   41.2    5.1    47
# ...

# %%
## Part 2 - Retreiving additional data on openweathermap

# %%
# Dependencies
import json
import requests
from config import api_key
